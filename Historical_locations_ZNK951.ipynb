# %%
import pandas as pd
import numpy as np

# %%
df_ZNK951 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNK951.csv')

# %%
df_ZNK951.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42651 entries, 0 to 42650
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     42651 non-null  int64
#  1   Unit         42651 non-null  object
#  2   Events       42651 non-null  object
#  3   Date         42651 non-null  object
#  4   Landmark     10996 non-null  object
#  5   Address      42229 non-null  object
#  6   Speed        42651 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       42651 non-null  object
#  9   Latitude     42651 non-null  float64
#  10  Longitude    42651 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 3.6+ MB

# %%
df_ZNK951_filter1=df_ZNK951[['Unit','Events','Date','Landmark']]
df_ZNK951_filter1
# Out:
#          Unit  Events                  Date         Landmark
# 0      ZNK951   Drive  Sep 27 2024 05:55 PM              NaN
# 1      ZNK951   Drive  Sep 27 2024 05:55 PM              NaN
# 2      ZNK951   Drive  Sep 27 2024 05:54 PM              NaN
# 3      ZNK951   Drive  Sep 27 2024 05:53 PM              NaN
# 4      ZNK951   Drive  Sep 27 2024 05:52 PM              NaN
# ...       ...     ...                   ...              ...
# 42646  ZNK951  Parked  Jul 30 2024 04:21 AM  Parqueadero TLQ
# 42647  ZNK951  Parked  Jul 30 2024 03:21 AM  Parqueadero TLQ
# 42648  ZNK951  Parked  Jul 30 2024 02:21 AM  Parqueadero TLQ
# 42649  ZNK951  Parked  Jul 30 2024 01:21 AM  Parqueadero TLQ
# 42650  ZNK951  Parked  Jul 30 2024 12:20 AM  Parqueadero TLQ
#
# [42651 rows x 4 columns]

# %%
df_ZNK951_geo_land_pu=df_ZNK951_filter1[
    (df_ZNK951_filter1['Events']=='Geofence IN')|
    (df_ZNK951_filter1['Events']=='Geofence OUT')|
    (df_ZNK951_filter1['Events']=='Landmark IN') |
    (df_ZNK951_filter1['Events']=='Landmark OUT')|
    (df_ZNK951_filter1['Events']=='POWER UP')|
    (df_ZNK951_filter1['Events']=='Ignition ON')]
df_ZNK951_geo_land_pu
# Out:
#          Unit        Events                  Date                Landmark
# 105    ZNK951  Landmark OUT  Sep 27 2024 04:42 PM          Peaje Acapulco
# 106    ZNK951   Landmark IN  Sep 27 2024 04:41 PM          Peaje Acapulco
# 160    ZNK951  Landmark OUT  Sep 27 2024 03:59 PM       El 41 - La Felisa
# 163    ZNK951   Landmark IN  Sep 27 2024 03:58 PM       El 41 - La Felisa
# 227    ZNK951  Landmark OUT  Sep 27 2024 03:20 PM               La Fesisa
# ...       ...           ...                   ...                     ...
# 42635  ZNK951  Geofence OUT  Jul 30 2024 07:34 AM  Parqueadero Yumbo 2011
# 42636  ZNK951  Geofence OUT  Jul 30 2024 07:34 AM           Geo Parq. TLQ
# 42638  ZNK951  Landmark OUT  Jul 30 2024 07:34 AM            PEAJE CENCAR
# 42640  ZNK951      POWER UP  Jul 30 2024 07:34 AM                     NaN
# 42642  ZNK951   Ignition ON  Jul 30 2024 07:33 AM         Parqueadero TLQ
#
# [3356 rows x 4 columns]

# %%
df_ZNK951_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNK951_geo_land_pu.csv', index=False)
