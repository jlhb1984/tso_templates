# %%
import pandas as pd
import numpy as np

# %%
df_SBH337 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_SBH337.csv')

# %%
df_SBH337.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20876 entries, 0 to 20875
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     20876 non-null  int64
#  1   Unit         20876 non-null  object
#  2   Events       20876 non-null  object
#  3   Date         20876 non-null  object
#  4   Landmark     13134 non-null  object
#  5   Address      20845 non-null  object
#  6   Speed        20876 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       20876 non-null  object
#  9   Latitude     20876 non-null  float64
#  10  Longitude    20876 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.8+ MB

# %%
df_SBH337_filter1=df_SBH337[['Unit','Events','Date','Landmark']]
df_SBH337_filter1
# Out:
#          Unit            Events                  Date          Landmark
# 0      SBH337            Parked  Sep 28 2024 11:00 AM   Parqueadero TLQ
# 1      SBH337            Parked  Sep 28 2024 11:00 AM   Parqueadero TLQ
# 2      SBH337  Towing/Drifting?  Sep 28 2024 11:00 AM   Parqueadero TLQ
# 3      SBH337      Ignition OFF  Sep 28 2024 11:00 AM   Parqueadero TLQ
# 4      SBH337       Idle - Stop  Sep 28 2024 10:59 AM   Parqueadero TLQ
# ...       ...               ...                   ...               ...
# 20871  SBH337            Parked  Jul 30 2024 05:00 AM  Sucroal Porteria
# 20872  SBH337            Parked  Jul 30 2024 03:59 AM  Sucroal Porteria
# 20873  SBH337            Parked  Jul 30 2024 02:59 AM  Sucroal Porteria
# 20874  SBH337            Parked  Jul 30 2024 01:59 AM  Sucroal Porteria
# 20875  SBH337            Parked  Jul 30 2024 12:59 AM  Sucroal Porteria
#
# [20876 rows x 4 columns]

# %%
df_SBH337_geo_land_pu=df_SBH337_filter1[
    (df_SBH337_filter1['Events']=='Geofence IN')|
    (df_SBH337_filter1['Events']=='Geofence OUT')|
    (df_SBH337_filter1['Events']=='Landmark IN') |
    (df_SBH337_filter1['Events']=='Landmark OUT')|
    (df_SBH337_filter1['Events']=='POWER UP')|
    (df_SBH337_filter1['Events']=='Ignition ON')]
df_SBH337_geo_land_pu
# Out:
#          Unit        Events                  Date                    Landmark
# 5      SBH337   Geofence IN  Sep 28 2024 10:58 AM      Parqueadero Yumbo 2011
# 7      SBH337   Geofence IN  Sep 28 2024 10:57 AM               Geo Parq. TLQ
# 8      SBH337   Landmark IN  Sep 28 2024 10:57 AM             Parqueadero TLQ
# 13     SBH337  Landmark OUT  Sep 28 2024 10:55 AM       Ecotechs laboratorios
# 15     SBH337   Landmark IN  Sep 28 2024 10:55 AM       Ecotechs laboratorios
# ...       ...           ...                   ...                         ...
# 20837  SBH337   Landmark IN  Jul 30 2024 07:05 AM  Crucero Palmira Candelaria
# 20842  SBH337  Landmark OUT  Jul 30 2024 07:01 AM     Retorno Palm-Candelaria
# 20846  SBH337   Landmark IN  Jul 30 2024 07:00 AM     Retorno Palm-Candelaria
# 20854  SBH337  Landmark OUT  Jul 30 2024 06:54 AM            Sucroal Porteria
# 20869  SBH337   Ignition ON  Jul 30 2024 06:46 AM            Sucroal Porteria
#
# [2383 rows x 4 columns]

# %%
df_SBH337_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_SBH337_geo_land_pu.csv', index=False)
