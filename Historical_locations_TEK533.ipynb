# %%
import pandas as pd
import numpy as np

# %%
df_TEK533 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TEK533.csv')

# %%
df_TEK533.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28299 entries, 0 to 28298
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     28299 non-null  int64
#  1   Unit         28299 non-null  object
#  2   Events       28299 non-null  object
#  3   Date         28299 non-null  object
#  4   Landmark     9902 non-null   object
#  5   Address      28266 non-null  object
#  6   Speed        28299 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       28299 non-null  object
#  9   Latitude     28299 non-null  float64
#  10  Longitude    28299 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.4+ MB

# %%
df_TEK533_filter1=df_TEK533[['Unit','Events','Date','Landmark']]
df_TEK533_filter1
# Out:
#          Unit            Events                  Date          Landmark
# 0      TEK533            Parked  Sep 28 2024 11:08 AM               NaN
# 1      TEK533            Parked  Sep 28 2024 10:08 AM               NaN
# 2      TEK533      Landmark OUT  Sep 28 2024 10:08 AM  Sucroal Porteria
# 3      TEK533            Parked  Sep 28 2024 10:08 AM  Sucroal Porteria
# 4      TEK533  Towing/Drifting?  Sep 28 2024 10:07 AM  Sucroal Porteria
# ...       ...               ...                   ...               ...
# 28294  TEK533            Parked  Jul 30 2024 04:44 AM   Parqueadero TLQ
# 28295  TEK533            Parked  Jul 30 2024 03:44 AM   Parqueadero TLQ
# 28296  TEK533            Parked  Jul 30 2024 02:44 AM   Parqueadero TLQ
# 28297  TEK533            Parked  Jul 30 2024 01:44 AM   Parqueadero TLQ
# 28298  TEK533            Parked  Jul 30 2024 12:44 AM   Parqueadero TLQ
#
# [28299 rows x 4 columns]

# %%
df_TEK533_geo_land_pu=df_TEK533_filter1[
    (df_TEK533_filter1['Events']=='Geofence IN')|
    (df_TEK533_filter1['Events']=='Geofence OUT')|
    (df_TEK533_filter1['Events']=='Landmark IN') |
    (df_TEK533_filter1['Events']=='Landmark OUT')|
    (df_TEK533_filter1['Events']=='POWER UP')|
    (df_TEK533_filter1['Events']=='Ignition ON')]
df_TEK533_geo_land_pu
# Out:
#          Unit        Events                  Date                    Landmark
# 2      TEK533  Landmark OUT  Sep 28 2024 10:08 AM            Sucroal Porteria
# 57     TEK533   Ignition ON  Sep 28 2024 09:29 AM            Sucroal Porteria
# 119    TEK533   Landmark IN  Sep 27 2024 06:48 PM            Sucroal Porteria
# 141    TEK533  Landmark OUT  Sep 27 2024 06:34 PM  Crucero Palmira Candelaria
# 144    TEK533   Landmark IN  Sep 27 2024 06:33 PM  Crucero Palmira Candelaria
# ...       ...           ...                   ...                         ...
# 28270  TEK533  Landmark OUT  Jul 30 2024 05:40 AM  Laboratorios Dermanat S.A.
# 28272  TEK533  Geofence OUT  Jul 30 2024 05:39 AM      Parqueadero Yumbo 2011
# 28273  TEK533  Geofence OUT  Jul 30 2024 05:39 AM               Geo Parq. TLQ
# 28274  TEK533   Landmark IN  Jul 30 2024 05:39 AM  Laboratorios Dermanat S.A.
# 28293  TEK533   Ignition ON  Jul 30 2024 05:30 AM             Parqueadero TLQ
#
# [2352 rows x 4 columns]

# %%
df_TEK533_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TEK533_geo_land_pu.csv', index=False)
