# %%
import pandas as pd
import numpy as np

# %%
df_TJW512 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TJW512.csv')

# %%
df_TJW512.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34049 entries, 0 to 34048
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     34049 non-null  int64
#  1   Unit         34049 non-null  object
#  2   Events       34049 non-null  object
#  3   Date         34049 non-null  object
#  4   Landmark     14604 non-null  object
#  5   Address      34015 non-null  object
#  6   Speed        34049 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       34049 non-null  object
#  9   Latitude     34049 non-null  float64
#  10  Longitude    34049 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.9+ MB

# %%
df_TJW512_filter1=df_TJW512[['Unit','Events','Date','Landmark']]
df_TJW512_filter1
# Out:
#          Unit  Events                  Date          Landmark
# 0      TJW512   Drive  Sep 28 2024 10:58 AM               NaN
# 1      TJW512   Drive  Sep 28 2024 10:58 AM               NaN
# 2      TJW512   Drive  Sep 28 2024 10:57 AM               NaN
# 3      TJW512   Drive  Sep 28 2024 10:57 AM               NaN
# 4      TJW512   Drive  Sep 28 2024 10:56 AM               NaN
# ...       ...     ...                   ...               ...
# 34044  TJW512  Parked  Jul 30 2024 04:33 AM  parq. Villa Yoly
# 34045  TJW512  Parked  Jul 30 2024 03:33 AM  parq. Villa Yoly
# 34046  TJW512  Parked  Jul 30 2024 02:33 AM  parq. Villa Yoly
# 34047  TJW512  Parked  Jul 30 2024 01:32 AM  parq. Villa Yoly
# 34048  TJW512  Parked  Jul 30 2024 12:32 AM  parq. Villa Yoly
#
# [34049 rows x 4 columns]

# %%
df_TJW512_geo_land_pu=df_TJW512_filter1[
    (df_TJW512_filter1['Events']=='Geofence IN')|
    (df_TJW512_filter1['Events']=='Geofence OUT')|
    (df_TJW512_filter1['Events']=='Landmark IN') |
    (df_TJW512_filter1['Events']=='Landmark OUT')|
    (df_TJW512_filter1['Events']=='POWER UP')|
    (df_TJW512_filter1['Events']=='Ignition ON')]
df_TJW512_geo_land_pu
# Out:
#          Unit        Events                  Date                Landmark
# 39     TJW512   Ignition ON  Sep 28 2024 10:31 AM                     NaN
# 66     TJW512   Ignition ON  Sep 28 2024 10:07 AM                     NaN
# 138    TJW512   Ignition ON  Sep 28 2024 08:42 AM                     NaN
# 249    TJW512  Landmark OUT  Sep 28 2024 07:05 AM             PC LA PAILA
# 251    TJW512   Landmark IN  Sep 28 2024 07:04 AM             PC LA PAILA
# ...       ...           ...                   ...                     ...
# 34005  TJW512   Landmark IN  Jul 30 2024 06:11 AM  Parmalat Colombia LTDA
# 34012  TJW512  Landmark OUT  Jul 30 2024 06:08 AM           Quimicol Ltda
# 34014  TJW512   Landmark IN  Jul 30 2024 06:08 AM           Quimicol Ltda
# 34031  TJW512  Landmark OUT  Jul 30 2024 05:55 AM        parq. Villa Yoly
# 34041  TJW512   Ignition ON  Jul 30 2024 05:48 AM        parq. Villa Yoly
#
# [3182 rows x 4 columns]

# %%
df_TJW512_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TJW512_geo_land_pu.csv', index=False)
