# %%
import pandas as pd
import numpy as np

# %%
df_TSV916 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TSV916.csv')

# %%
df_TSV916.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15536 entries, 0 to 15535
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     15536 non-null  int64
#  1   Unit         15536 non-null  object
#  2   Events       15536 non-null  object
#  3   Date         15536 non-null  object
#  4   Landmark     4223 non-null   object
#  5   Address      15389 non-null  object
#  6   Speed        15536 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       15536 non-null  object
#  9   Latitude     15536 non-null  float64
#  10  Longitude    15536 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.3+ MB

# %%
df_TSV916_filter1=df_TSV916[['Unit','Events','Date','Landmark']]
df_TSV916_filter1
# Out:
#          Unit        Events                  Date      Landmark
# 0      TSV916   Travel Stop  Sep 28 2024 10:10 AM           NaN
# 1      TSV916  Travel Start  Sep 28 2024 10:08 AM           NaN
# 2      TSV916   Travel Stop  Sep 28 2024 10:07 AM           NaN
# 3      TSV916  Travel Start  Sep 28 2024 10:05 AM           NaN
# 4      TSV916   Travel Stop  Sep 28 2024 10:04 AM           NaN
# ...       ...           ...                   ...           ...
# 15531  TSV916    Idle Alert  Jul 30 2024 06:39 AM  PEAJE TARAZA
# 15532  TSV916  Landmark OUT  Jul 30 2024 06:37 AM  PEAJE CENCAR
# 15533  TSV916   Idle - Stop  Jul 30 2024 06:37 AM  PEAJE CENCAR
# 15534  TSV916   Ignition ON  Jul 30 2024 06:35 AM           NaN
# 15535  TSV916      POWER UP  Jul 30 2024 06:35 AM           NaN
#
# [15536 rows x 4 columns]

# %%
df_TSV916_geo_land_pu=df_TSV916_filter1[
    (df_TSV916_filter1['Events']=='Geofence IN')|
    (df_TSV916_filter1['Events']=='Geofence OUT')|
    (df_TSV916_filter1['Events']=='Landmark IN') |
    (df_TSV916_filter1['Events']=='Landmark OUT')|
    (df_TSV916_filter1['Events']=='POWER UP')|
    (df_TSV916_filter1['Events']=='Ignition ON')]
df_TSV916_geo_land_pu
# Out:
#          Unit        Events                  Date           Landmark
# 15     TSV916  Landmark OUT  Sep 28 2024 09:50 AM        Casa Tarros
# 16     TSV916   Landmark IN  Sep 28 2024 09:49 AM        Casa Tarros
# 20     TSV916   Ignition ON  Sep 28 2024 09:45 AM                NaN
# 25     TSV916  Landmark OUT  Sep 28 2024 09:23 AM   Alexander Chacon
# 27     TSV916   Landmark IN  Sep 28 2024 09:21 AM   Alexander Chacon
# ...       ...           ...                   ...                ...
# 15528  TSV916  Landmark OUT  Jul 30 2024 06:44 AM  PEAJE DE PAILITAS
# 15530  TSV916  Landmark OUT  Jul 30 2024 06:39 AM       PEAJE TARAZA
# 15532  TSV916  Landmark OUT  Jul 30 2024 06:37 AM       PEAJE CENCAR
# 15534  TSV916   Ignition ON  Jul 30 2024 06:35 AM                NaN
# 15535  TSV916      POWER UP  Jul 30 2024 06:35 AM                NaN
#
# [2380 rows x 4 columns]

# %%
df_TSV916_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TSV916_geo_land_pu.csv', index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
