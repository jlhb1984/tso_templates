# %%
import pandas as pd
import numpy as np

# %%
df_books=pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Customer-Units.csv')
df_books.head(2)
# Out:
#         ID    Owner Unit ID    Unit  Peripherals  Reporting Status  \
# 0    17592  Renting    5775  ZNN824          NaN               NaN
# 1  1036105  Renting    603A  ZNM766          NaN               NaN
#
#    Show Until  Billing Group Last Event Date  Monthly Fee  ...  \
# 0         NaN            NaN       9/26/2024        65697  ...
# 1         NaN            NaN       9/26/2024        52000  ...
#
#      Assigned to Company IFTA History Months Comments       Warranty Expires  \
# 0   5/20/2024 4:29:02 PM    N              3        Y  4/19/2009 12:00:00 AM
# 1  11/23/2018 5:30:59 PM    N              3      NaN  7/10/2015 12:00:00 AM
#
#                                 Script         JBOX Profile  Contract Type  \
# 0  TSO_LMU3x0_Basic_BIKE_10S_AWS_10700                  NaN            NaN
# 1                                  NaN  ELD_STD + DeltaFuel            NaN
#
#   Subscription                           Firmware
# 0          NaN                                NaN
# ...

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       32 non-null     int64
#  1   Owner                    32 non-null     object
#  2   Unit ID                  32 non-null     object
#  3   Unit                     32 non-null     object
#  4   Peripherals              0 non-null      float64
#  5   Reporting Status         0 non-null      float64
#  6   Show Until               0 non-null      float64
#  7   Billing Group            0 non-null      float64
#  8   Last Event Date          32 non-null     object
#  9   Monthly Fee              32 non-null     int64
#  10  Bill To                  18 non-null     object
#  11  Assigned To              32 non-null     object
#  12  Billable                 32 non-null     object
#  13  RMA                      32 non-null     object
# ...

# %%
df_books_firmware_scripts=df_books[['Serial Number','IMEI','Unit Type','Unit','Firmware','Script']]
df_books_firmware_scripts
# Out:
#       Serial Number             IMEI  \
# 0        1363189344  352556102948028
# 1   S2-M006820-0WMJ  868574041208021
# 2      000003849921  357852031825840
# 3   S2-M007693-0XM2  868574042406905
# 4   S2-M006820-0XPN  868574041211553
# 5   S2-M006820-0WKS  868574041240982
# 6      000003919546  355233050977303
# 7   S2-M007693-173G  868574042744552
# 8        4764247261  357041064217964
# 9   S2-M007693-14H9  868574042925045
# 10  S2-M006820-0XLU  868574041382453
# 11  S2-M006820-0WMM  868574041211504
# 12  S2-M007693-724A  868574042445937
# 13     000034410489  359316071133539
# 14     000003914577  358696042804016
# 15  S2-M007693-0XDF  868574042453204
# 16     000034400332  353816054975398
# 17     000036081616  357520074884277
# 18  S2-M007693-0XJK  868574042408307
# 19  S2-M007693-0XHO  868574042384854
# 20       4634529740  351628098533071
# 21  S2-M006820-0XLM  868574041252474
# 22  S2-M007693-250A  868574042436373
# 23     000003952450  359394056393089
# ...

# %%
df_books_firmware_scripts['Nuevo script']=np.nan
# Out:
# <ipython-input-48-9062385f2974>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_firmware_scripts['Nuevo script']=np.nan

# %%
df_books_firmware_scripts['Nuevo firmware']=np.nan
# Out:
# <ipython-input-49-185322f02c38>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_books_firmware_scripts['Nuevo firmware']=np.nan

# %%
df_books_firmware_scripts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Serial Number   32 non-null     object
#  1   IMEI            32 non-null     int64
#  2   Unit Type       32 non-null     object
#  3   Unit            32 non-null     object
#  4   Firmware        27 non-null     object
#  5   Script          15 non-null     object
#  6   Nuevo script    0 non-null      float64
#  7   Nuevo firmware  0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.1+ KB

# %%
df_books_firmware_scripts
# Out:
#       Serial Number             IMEI  \
# 0        1363189344  352556102948028
# 1   S2-M006820-0WMJ  868574041208021
# 2      000003849921  357852031825840
# 3   S2-M007693-0XM2  868574042406905
# 4   S2-M006820-0XPN  868574041211553
# 5   S2-M006820-0WKS  868574041240982
# 6      000003919546  355233050977303
# 7   S2-M007693-173G  868574042744552
# 8        4764247261  357041064217964
# 9   S2-M007693-14H9  868574042925045
# 10  S2-M006820-0XLU  868574041382453
# 11  S2-M006820-0WMM  868574041211504
# 12  S2-M007693-724A  868574042445937
# 13     000034410489  359316071133539
# 14     000003914577  358696042804016
# 15  S2-M007693-0XDF  868574042453204
# 16     000034400332  353816054975398
# 17     000036081616  357520074884277
# 18  S2-M007693-0XJK  868574042408307
# 19  S2-M007693-0XHO  868574042384854
# 20       4634529740  351628098533071
# 21  S2-M006820-0XLM  868574041252474
# 22  S2-M007693-250A  868574042436373
# 23     000003952450  359394056393089
# ...

# %%
df_books_firmware_scripts.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_books_firmware_scripts.csv', index=False)
