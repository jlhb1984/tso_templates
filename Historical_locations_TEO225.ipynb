# %%
import pandas as pd
import numpy as np

# %%
df_TEO225 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TEO225.csv')

# %%
df_TEO225.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11190 entries, 0 to 11189
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     11190 non-null  int64
#  1   Unit         11190 non-null  object
#  2   Events       11190 non-null  object
#  3   Date         11190 non-null  object
#  4   Landmark     4328 non-null   object
#  5   Address      11188 non-null  object
#  6   Speed        11190 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       11190 non-null  object
#  9   Latitude     11190 non-null  float64
#  10  Longitude    11190 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 961.8+ KB

# %%
df_TEO225_filter1=df_TEO225[['Unit','Events','Date','Landmark']]
df_TEO225_filter1
# Out:
#           Unit        Events                  Date            Landmark
# 0      TEO225         Parked  Sep 28 2024 10:48 AM  Sucroal Descargue.
# 1      TEO225         Parked  Sep 28 2024 09:59 AM  Sucroal Descargue.
# 2      TEO225   Ignition OFF  Sep 28 2024 09:48 AM  Sucroal Descargue.
# 3      TEO225     Idle Alert  Sep 28 2024 09:46 AM  Sucroal Descargue.
# 4      TEO225      First Fix  Sep 28 2024 09:42 AM  Sucroal Descargue.
# ...        ...           ...                   ...                 ...
# 11185  TEO225         Parked  Jul 30 2024 04:26 AM   EDS Yired Pradera
# 11186  TEO225         Parked  Jul 30 2024 03:26 AM   EDS Yired Pradera
# 11187  TEO225         Parked  Jul 30 2024 02:25 AM   EDS Yired Pradera
# 11188  TEO225         Parked  Jul 30 2024 01:25 AM   EDS Yired Pradera
# 11189  TEO225         Parked  Jul 30 2024 12:25 AM   EDS Yired Pradera
#
# [11190 rows x 4 columns]

# %%
df_TEO225_geo_land_pu=df_TEO225_filter1[
    (df_TEO225_filter1['Events']=='Geofence IN')|
    (df_TEO225_filter1['Events']=='Geofence OUT')|
    (df_TEO225_filter1['Events']=='Landmark IN') |
    (df_TEO225_filter1['Events']=='Landmark OUT')|
    (df_TEO225_filter1['Events']=='POWER UP')|
    (df_TEO225_filter1['Events']=='Ignition ON')]
df_TEO225_geo_land_pu
# Out:
#           Unit        Events                  Date                    Landmark
# 5      TEO225    Ignition ON  Sep 28 2024 09:41 AM          Sucroal Descargue.
# 7      TEO225    Landmark IN  Sep 28 2024 08:54 AM          Sucroal Descargue.
# 12     TEO225   Landmark OUT  Sep 28 2024 08:39 AM            Sucroal Porteria
# 16     TEO225    Ignition ON  Sep 28 2024 08:10 AM            Sucroal Porteria
# 55     TEO225    Landmark IN  Sep 26 2024 08:31 PM            Sucroal Porteria
# ...        ...           ...                   ...                         ...
# 11128  TEO225    Landmark IN  Jul 31 2024 12:20 PM            Sucroal Porteria
# 11131  TEO225   Landmark OUT  Jul 31 2024 12:17 PM  Crucero Palmira Candelaria
# 11135  TEO225    Landmark IN  Jul 31 2024 12:15 PM  Crucero Palmira Candelaria
# 11149  TEO225   Landmark OUT  Jul 31 2024 11:49 AM           EDS Yired Pradera
# 11153  TEO225    Ignition ON  Jul 31 2024 11:38 AM           EDS Yired Pradera
#
# [1512 rows x 4 columns]

# %%
df_TEO225_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TEO225_geo_land_pu.csv', index=False)
