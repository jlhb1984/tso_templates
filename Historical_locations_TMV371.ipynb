# %%
import pandas as pd
import numpy as np

# %%
df_TMV371 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TMV371.csv')

# %%
df_TMV371.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38178 entries, 0 to 38177
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     38178 non-null  int64
#  1   Unit         38178 non-null  object
#  2   Events       38178 non-null  object
#  3   Date         38178 non-null  object
#  4   Landmark     18266 non-null  object
#  5   Address      38148 non-null  object
#  6   Speed        38178 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       38178 non-null  object
#  9   Latitude     38178 non-null  float64
#  10  Longitude    38178 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 3.2+ MB

# %%
df_TMV371_filter1=df_TMV371[['Unit','Events','Date','Landmark']]
df_TMV371_filter1
# Out:
#          Unit       Events                  Date           Landmark
# 0      TMV371  Idle - Stop  Sep 28 2024 10:32 AM  parq. La Trinidad
# 1      TMV371  Idle - Stop  Sep 28 2024 10:32 AM  parq. La Trinidad
# 2      TMV371  Idle - Stop  Sep 28 2024 10:31 AM  parq. La Trinidad
# 3      TMV371  Idle - Stop  Sep 28 2024 10:31 AM  parq. La Trinidad
# 4      TMV371  Idle - Stop  Sep 28 2024 10:31 AM  parq. La Trinidad
# ...       ...          ...                   ...                ...
# 38173  TMV371       Parked  Jul 30 2024 04:23 AM  parq. La Trinidad
# 38174  TMV371       Parked  Jul 30 2024 03:22 AM  parq. La Trinidad
# 38175  TMV371       Parked  Jul 30 2024 02:22 AM  parq. La Trinidad
# 38176  TMV371       Parked  Jul 30 2024 01:22 AM  parq. La Trinidad
# 38177  TMV371       Parked  Jul 30 2024 12:22 AM  parq. La Trinidad
#
# [38178 rows x 4 columns]

# %%
df_TMV371_geo_land_pu=df_TMV371_filter1[
    (df_TMV371_filter1['Events']=='Geofence IN')|
    (df_TMV371_filter1['Events']=='Geofence OUT')|
    (df_TMV371_filter1['Events']=='Landmark IN') |
    (df_TMV371_filter1['Events']=='Landmark OUT')|
    (df_TMV371_filter1['Events']=='POWER UP')|
    (df_TMV371_filter1['Events']=='Ignition ON')]
df_TMV371_geo_land_pu
# Out:
#          Unit        Events                  Date               Landmark
# 5      TMV371   Ignition ON  Sep 28 2024 10:31 AM      parq. La Trinidad
# 27     TMV371   Landmark IN  Sep 27 2024 03:41 PM      parq. La Trinidad
# 36     TMV371  Landmark OUT  Sep 27 2024 03:36 PM  Tecnologias Aplicadas
# 50     TMV371   Landmark IN  Sep 27 2024 03:28 PM  Tecnologias Aplicadas
# 57     TMV371  Landmark OUT  Sep 27 2024 03:24 PM      parq. La Gran Via
# ...       ...           ...                   ...                    ...
# 38135  TMV371   Landmark IN  Jul 30 2024 06:01 AM          Quimicol Ltda
# 38153  TMV371  Landmark OUT  Jul 30 2024 05:48 AM  Tecnologias Aplicadas
# 38158  TMV371   Landmark IN  Jul 30 2024 05:45 AM  Tecnologias Aplicadas
# 38166  TMV371  Landmark OUT  Jul 30 2024 05:41 AM      parq. La Trinidad
# 38171  TMV371   Ignition ON  Jul 30 2024 05:39 AM      parq. La Trinidad
#
# [2461 rows x 4 columns]

# %%
df_TMV371_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TMV371_geo_land_pu.csv', index=False)
