# %%
import pandas as pd
import numpy as np

# %%
df_STX820 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_STX820.csv')

# %%
df_STX820.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10238 entries, 0 to 10237
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     10238 non-null  int64
#  1   Unit         10238 non-null  object
#  2   Events       10238 non-null  object
#  3   Date         10238 non-null  object
#  4   Landmark     2820 non-null   object
#  5   Address      10233 non-null  object
#  6   Speed        10238 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       10238 non-null  object
#  9   Latitude     10238 non-null  float64
#  10  Longitude    10238 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 880.0+ KB

# %%
df_STX820_filter1=df_STX820[['Unit','Events','Date','Landmark']]
df_STX820_filter1
# Out:
#          Unit        Events                  Date            Landmark
# 0      STX820  Landmark OUT  Sep 27 2024 09:50 AM  parq. Los Imperios
# 1      STX820  Ignition OFF  Sep 27 2024 09:50 AM  parq. Los Imperios
# 2      STX820         Drive  Sep 27 2024 09:50 AM    parq. El Imperio
# 3      STX820   Landmark IN  Sep 27 2024 09:50 AM    parq. El Imperio
# 4      STX820         Drive  Sep 27 2024 09:49 AM  parq. Los Imperios
# ...       ...           ...                   ...                 ...
# 10233  STX820  Landmark OUT  Jul 30 2024 06:37 AM    Sucroal Porteria
# 10234  STX820     First Fix  Jul 30 2024 06:30 AM    Sucroal Porteria
# 10235  STX820      POWER UP  Jul 30 2024 06:29 AM    Sucroal Porteria
# 10236  STX820   Ignition ON  Jul 30 2024 06:29 AM    Sucroal Porteria
# 10237  STX820      POWER UP  Jul 30 2024 06:29 AM    Sucroal Porteria
#
# [10238 rows x 4 columns]

# %%
df_STX820_geo_land_pu=df_STX820_filter1[
    (df_STX820_filter1['Events']=='Geofence IN')|
    (df_STX820_filter1['Events']=='Geofence OUT')|
    (df_STX820_filter1['Events']=='Landmark IN') |
    (df_STX820_filter1['Events']=='Landmark OUT')|
    (df_STX820_filter1['Events']=='POWER UP')|
    (df_STX820_filter1['Events']=='Ignition ON')]
df_STX820_geo_land_pu
# Out:
#          Unit        Events                  Date                 Landmark
# 0      STX820  Landmark OUT  Sep 27 2024 09:50 AM       parq. Los Imperios
# 3      STX820   Landmark IN  Sep 27 2024 09:50 AM         parq. El Imperio
# 5      STX820   Landmark IN  Sep 27 2024 09:49 AM       parq. Los Imperios
# 8      STX820  Landmark OUT  Sep 27 2024 09:39 AM  Retorno Palm-Candelaria
# 10     STX820   Landmark IN  Sep 27 2024 09:33 AM  Retorno Palm-Candelaria
# ...       ...           ...                   ...                      ...
# 10231  STX820   Landmark IN  Jul 30 2024 06:38 AM         Sucroal Porteria
# 10233  STX820  Landmark OUT  Jul 30 2024 06:37 AM         Sucroal Porteria
# 10235  STX820      POWER UP  Jul 30 2024 06:29 AM         Sucroal Porteria
# 10236  STX820   Ignition ON  Jul 30 2024 06:29 AM         Sucroal Porteria
# 10237  STX820      POWER UP  Jul 30 2024 06:29 AM         Sucroal Porteria
#
# [1272 rows x 4 columns]

# %%
df_STX820_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_STX820_geo_land_pu.csv', index=False)
