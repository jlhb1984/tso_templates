# %%
import pandas as pd
import numpy as np

# %%
df_VMU499 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VMU499.csv')

# %%
df_VMU499.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5412 entries, 0 to 5411
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     5412 non-null   int64
#  1   Unit         5412 non-null   object
#  2   Events       5412 non-null   object
#  3   Date         5412 non-null   object
#  4   Landmark     4217 non-null   object
#  5   Address      5411 non-null   object
#  6   Speed        5412 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       5412 non-null   object
#  9   Latitude     5412 non-null   float64
#  10  Longitude    5412 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 465.2+ KB

# %%
df_VMU499_filter1=df_VMU499[['Unit','Events','Date','Landmark']]
df_VMU499_filter1
# Out:
#         Unit        Events                  Date                 Landmark
# 0     VMU499        Parked  Sep 28 2024 08:48 AM         parq. La Luciana
# 1     VMU499  Ignition OFF  Sep 28 2024 08:38 AM         parq. La Luciana
# 2     VMU499   Landmark IN  Sep 28 2024 08:35 AM  parqueadero El  cortijo
# 3     VMU499   Idle - Stop  Sep 28 2024 08:35 AM  parqueadero El  cortijo
# 4     VMU499         Drive  Sep 28 2024 08:34 AM         perimetro urbano
# ...      ...           ...                   ...                      ...
# 5407  VMU499    Idle Alert  Jul 30 2024 05:54 AM         parq. La Luciana
# 5408  VMU499        Parked  Jul 30 2024 05:03 AM         parq. La Luciana
# 5409  VMU499        Parked  Jul 30 2024 04:03 AM         parq. La Luciana
# 5410  VMU499        Parked  Jul 30 2024 03:03 AM         parq. La Luciana
# 5411  VMU499        Parked  Jul 30 2024 01:03 AM         parq. La Luciana
#
# [5412 rows x 4 columns]

# %%
df_VMU499_geo_land_pu=df_VMU499_filter1[
    (df_VMU499_filter1['Events']=='Geofence IN')|
    (df_VMU499_filter1['Events']=='Geofence OUT')|
    (df_VMU499_filter1['Events']=='Landmark IN') |
    (df_VMU499_filter1['Events']=='Landmark OUT')|
    (df_VMU499_filter1['Events']=='POWER UP')|
    (df_VMU499_filter1['Events']=='Ignition ON')]
df_VMU499_geo_land_pu
# Out:
#         Unit        Events                  Date                 Landmark
# 2     VMU499   Landmark IN  Sep 28 2024 08:35 AM  parqueadero El  cortijo
# 7     VMU499  Landmark OUT  Sep 28 2024 08:33 AM    Empaques Flexibles SA
# 9     VMU499   Landmark IN  Sep 28 2024 08:31 AM    Empaques Flexibles SA
# 18    VMU499  Landmark OUT  Sep 28 2024 08:21 AM         Unilever Palmira
# 19    VMU499  Landmark OUT  Sep 28 2024 08:19 AM         Unilever Palmira
# ...      ...           ...                   ...                      ...
# 5400  VMU499   Geofence IN  Jul 30 2024 05:57 AM       Br Yumbo Z Parqueo
# 5401  VMU499   Landmark IN  Jul 30 2024 05:57 AM           Brenntag Yumbo
# 5404  VMU499  Landmark OUT  Jul 30 2024 05:56 AM         perimetro urbano
# 5405  VMU499  Landmark OUT  Jul 30 2024 05:56 AM  parqueadero El  cortijo
# 5406  VMU499   Landmark IN  Jul 30 2024 05:56 AM  parqueadero El  cortijo
#
# [2068 rows x 4 columns]

# %%
df_VMU499_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VMU499_geo_land_pu.csv', index=False)
