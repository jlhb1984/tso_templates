# %%
import pandas as pd
import numpy as np

# %%
df_VBW486 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VBW486.csv')

# %%
df_VBW486.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41118 entries, 0 to 41117
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     41118 non-null  int64
#  1   Unit         41118 non-null  object
#  2   Events       41118 non-null  object
#  3   Date         41118 non-null  object
#  4   Landmark     10885 non-null  object
#  5   Address      41085 non-null  object
#  6   Speed        41118 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       41118 non-null  object
#  9   Latitude     41118 non-null  float64
#  10  Longitude    41118 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 3.5+ MB

# %%
df_VBW486_filter1=df_VBW486[['Unit','Events','Date','Landmark']]
df_VBW486_filter1
# Out:
#          Unit       Events                  Date          Landmark
# 0      VBW486  Idle - Stop  Sep 28 2024 09:54 AM  Sucroal Porteria
# 1      VBW486  Idle - Stop  Sep 28 2024 09:53 AM  Sucroal Porteria
# 2      VBW486  Idle - Stop  Sep 28 2024 09:52 AM  Sucroal Porteria
# 3      VBW486  Idle - Stop  Sep 28 2024 09:52 AM  Sucroal Porteria
# 4      VBW486  Landmark IN  Sep 28 2024 09:51 AM  Sucroal Porteria
# ...       ...          ...                   ...               ...
# 41113  VBW486       Parked  Jul 30 2024 04:14 AM  Sucroal Porteria
# 41114  VBW486       Parked  Jul 30 2024 03:14 AM  Sucroal Porteria
# 41115  VBW486       Parked  Jul 30 2024 02:14 AM  Sucroal Porteria
# 41116  VBW486       Parked  Jul 30 2024 01:13 AM  Sucroal Porteria
# 41117  VBW486       Parked  Jul 30 2024 12:13 AM  Sucroal Porteria
#
# [41118 rows x 4 columns]

# %%
df_VBW486_geo_land_pu=df_VBW486_filter1[
    (df_VBW486_filter1['Events']=='Geofence IN')|
    (df_VBW486_filter1['Events']=='Geofence OUT')|
    (df_VBW486_filter1['Events']=='Landmark IN') |
    (df_VBW486_filter1['Events']=='Landmark OUT')|
    (df_VBW486_filter1['Events']=='POWER UP')|
    (df_VBW486_filter1['Events']=='Ignition ON')]
df_VBW486_geo_land_pu
# Out:
#          Unit        Events                  Date                    Landmark
# 4      VBW486   Landmark IN  Sep 28 2024 09:51 AM            Sucroal Porteria
# 10     VBW486  Landmark OUT  Sep 28 2024 09:47 AM  Crucero Palmira Candelaria
# 22     VBW486   Landmark IN  Sep 28 2024 09:45 AM  Crucero Palmira Candelaria
# 28     VBW486  Landmark OUT  Sep 28 2024 09:41 AM     Retorno Palm-Candelaria
# 30     VBW486  Landmark OUT  Sep 28 2024 09:41 AM     Retorno Palm-Candelaria
# ...       ...           ...                   ...                         ...
# 41072  VBW486   Landmark IN  Jul 30 2024 10:52 AM     Retorno Palm-Candelaria
# 41077  VBW486  Landmark OUT  Jul 30 2024 10:49 AM            Sucroal Porteria
# 41079  VBW486   Landmark IN  Jul 30 2024 10:47 AM            Sucroal Porteria
# 41083  VBW486  Landmark OUT  Jul 30 2024 10:46 AM            Sucroal Porteria
# 41106  VBW486   Ignition ON  Jul 30 2024 10:33 AM            Sucroal Porteria
#
# [2589 rows x 4 columns]

# %%
df_VBW486_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VBW486_geo_land_pu.csv', index=False)
