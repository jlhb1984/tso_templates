# %%
import pandas as pd
import numpy as np

# %%
df_YAP438 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_YAP438.csv')

# %%
df_YAP438.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9186 entries, 0 to 9185
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     9186 non-null   int64
#  1   Unit         9186 non-null   object
#  2   Events       9186 non-null   object
#  3   Date         9186 non-null   object
#  4   Landmark     5617 non-null   object
#  5   Address      9165 non-null   object
#  6   Speed        9186 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       3448 non-null   object
#  9   Latitude     9186 non-null   float64
#  10  Longitude    9186 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 789.5+ KB

# %%
df_YAP438_filter1=df_YAP438[['Unit','Events','Date','Landmark']]
df_YAP438_filter1
# Out:
#         Unit  Events                  Date         Landmark
# 0     YAP438  Parked  Sep 28 2024 07:30 AM  Parqueadero TLQ
# 1     YAP438  Parked  Sep 28 2024 06:30 AM  Parqueadero TLQ
# 2     YAP438  Parked  Sep 28 2024 05:30 AM  Parqueadero TLQ
# 3     YAP438  Parked  Sep 28 2024 04:30 AM  Parqueadero TLQ
# 4     YAP438  Parked  Sep 28 2024 03:30 AM  Parqueadero TLQ
# ...      ...     ...                   ...              ...
# 9181  YAP438  Parked  Jul 30 2024 04:55 AM  Parqueadero TLQ
# 9182  YAP438  Parked  Jul 30 2024 03:54 AM  Parqueadero TLQ
# 9183  YAP438  Parked  Jul 30 2024 02:54 AM  Parqueadero TLQ
# 9184  YAP438  Parked  Jul 30 2024 01:54 AM  Parqueadero TLQ
# 9185  YAP438  Parked  Jul 30 2024 12:54 AM  Parqueadero TLQ
#
# [9186 rows x 4 columns]

# %%
df_YAP438_geo_land_pu=df_YAP438_filter1[
    (df_YAP438_filter1['Events']=='Geofence IN')|
    (df_YAP438_filter1['Events']=='Geofence OUT')|
    (df_YAP438_filter1['Events']=='Landmark IN') |
    (df_YAP438_filter1['Events']=='Landmark OUT')|
    (df_YAP438_filter1['Events']=='POWER UP')|
    (df_YAP438_filter1['Events']=='Ignition ON')]
df_YAP438_geo_land_pu
# Out:
#         Unit        Events                  Date         Landmark
# 11    YAP438   Landmark IN  Sep 27 2024 08:29 PM  Parqueadero TLQ
# 13    YAP438  Landmark OUT  Sep 27 2024 08:29 PM     PEAJE CENCAR
# 15    YAP438      POWER UP  Sep 27 2024 08:28 PM              NaN
# 53    YAP438  Landmark OUT  Sep 27 2024 03:33 PM      PRODUVARIOS
# 54    YAP438   Landmark IN  Sep 27 2024 03:33 PM      PRODUVARIOS
# ...      ...           ...                   ...              ...
# 9142  YAP438   Ignition ON  Jul 30 2024 12:03 PM  Parqueadero TLQ
# 9161  YAP438   Ignition ON  Jul 30 2024 11:02 AM  Parqueadero TLQ
# 9165  YAP438   Ignition ON  Jul 30 2024 11:02 AM  Parqueadero TLQ
# 9170  YAP438   Ignition ON  Jul 30 2024 11:02 AM  Parqueadero TLQ
# 9173  YAP438   Ignition ON  Jul 30 2024 11:02 AM  Parqueadero TLQ
#
# [937 rows x 4 columns]

# %%
df_YAP438_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_YAP438_geo_land_pu.csv', index=False)
