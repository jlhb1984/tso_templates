# %%
import pandas as pd
import numpy as np

# %%
df_WTC924 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_WTC924.csv')

# %%
df_WTC924.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19986 entries, 0 to 19985
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     19986 non-null  int64
#  1   Unit         19986 non-null  object
#  2   Events       19986 non-null  object
#  3   Date         19986 non-null  object
#  4   Landmark     13006 non-null  object
#  5   Address      19952 non-null  object
#  6   Speed        19986 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       19986 non-null  object
#  9   Latitude     19986 non-null  float64
#  10  Longitude    19986 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.7+ MB

# %%
df_WTC924_filter1=df_WTC924[['Unit','Events','Date','Landmark']]
df_WTC924_filter1
# Out:
#          Unit       Events                  Date           Landmark
# 0      WTC924  Idle - Stop  Sep 28 2024 08:44 AM  parq. Chininangos
# 1      WTC924  Idle - Stop  Sep 28 2024 08:44 AM  parq. Chininangos
# 2      WTC924  Idle - Stop  Sep 28 2024 08:44 AM  parq. Chininangos
# 3      WTC924  Idle - Stop  Sep 28 2024 08:43 AM  parq. Chininangos
# 4      WTC924  Idle - Stop  Sep 28 2024 08:42 AM  parq. Chininangos
# ...       ...          ...                   ...                ...
# 19981  WTC924       Parked  Jul 30 2024 04:05 AM   Sucroal Porteria
# 19982  WTC924       Parked  Jul 30 2024 03:05 AM   Sucroal Porteria
# 19983  WTC924       Parked  Jul 30 2024 02:04 AM   Sucroal Porteria
# 19984  WTC924       Parked  Jul 30 2024 01:04 AM   Sucroal Porteria
# 19985  WTC924       Parked  Jul 30 2024 12:04 AM   Sucroal Porteria
#
# [19986 rows x 4 columns]

# %%
df_WTC924_geo_land_pu=df_WTC924_filter1[
    (df_WTC924_filter1['Events']=='Geofence IN')|
    (df_WTC924_filter1['Events']=='Geofence OUT')|
    (df_WTC924_filter1['Events']=='Landmark IN') |
    (df_WTC924_filter1['Events']=='Landmark OUT')|
    (df_WTC924_filter1['Events']=='POWER UP')|
    (df_WTC924_filter1['Events']=='Ignition ON')]
df_WTC924_geo_land_pu
# Out:
#          Unit        Events                  Date  \
# 15     WTC924   Ignition ON  Sep 28 2024 08:33 AM
# 19     WTC924   Ignition ON  Sep 28 2024 08:33 AM
# 21     WTC924   Landmark IN  Sep 28 2024 08:30 AM
# 27     WTC924   Ignition ON  Sep 28 2024 08:30 AM
# 32     WTC924   Ignition ON  Sep 28 2024 07:28 AM
# ...       ...           ...                   ...
# 19942  WTC924  Landmark OUT  Jul 30 2024 06:44 AM
# 19944  WTC924   Landmark IN  Jul 30 2024 06:43 AM
# 19946  WTC924  Landmark OUT  Jul 30 2024 06:42 AM
# 19972  WTC924   Ignition ON  Jul 30 2024 06:28 AM
# 19978  WTC924   Ignition ON  Jul 30 2024 06:27 AM
#
#                               Landmark
# 15                   parq. Chininangos
# 19                   parq. Chininangos
# 21                   parq. Chininangos
# 27     PARQUEADERO CHIMINANGOS PALMIRA
# 32     PARQUEADERO CHIMINANGOS PALMIRA
# ...                                ...
# 19942                 Sucroal Porteria
# 19944                 Sucroal Porteria
# ...

# %%
df_WTC924_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_WTC924_geo_land_pu.csv', index=False)
