# %%
import pandas as pd
import numpy as np

# %%
df_TMP155 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TMP155.csv')

# %%
df_TMP155.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7771 entries, 0 to 7770
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     7771 non-null   int64
#  1   Unit         7771 non-null   object
#  2   Events       7771 non-null   object
#  3   Date         7771 non-null   object
#  4   Landmark     5336 non-null   object
#  5   Address      7759 non-null   object
#  6   Speed        7771 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       7771 non-null   object
#  9   Latitude     7771 non-null   float64
#  10  Longitude    7771 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 667.9+ KB

# %%
df_TMP155_filter1=df_TMP155[['Unit','Events','Date','Landmark']]
df_TMP155_filter1
# Out:
#          Unit        Events                  Date          Landmark
# 0     TMP155   Ignition OFF  Sep 16 2024 04:38 PM  perimetro urbano
# 1     TMP155     Idle Alert  Sep 16 2024 04:33 PM  perimetro urbano
# 2     TMP155      First Fix  Sep 16 2024 04:32 PM  perimetro urbano
# 3     TMP155       POWER UP  Sep 16 2024 04:28 PM  perimetro urbano
# 4     TMP155    Ignition ON  Sep 16 2024 04:28 PM  perimetro urbano
# ...       ...           ...                   ...               ...
# 7766  TMP155         Parked  Jul 30 2024 04:53 AM  perimetro urbano
# 7767  TMP155         Parked  Jul 30 2024 03:53 AM  perimetro urbano
# 7768  TMP155         Parked  Jul 30 2024 02:53 AM  perimetro urbano
# 7769  TMP155         Parked  Jul 30 2024 01:53 AM  perimetro urbano
# 7770  TMP155         Parked  Jul 30 2024 12:53 AM  perimetro urbano
#
# [7771 rows x 4 columns]

# %%
df_TMP155_geo_land_pu=df_TMP155_filter1[
    (df_TMP155_filter1['Events']=='Geofence IN')|
    (df_TMP155_filter1['Events']=='Geofence OUT')|
    (df_TMP155_filter1['Events']=='Landmark IN') |
    (df_TMP155_filter1['Events']=='Landmark OUT')|
    (df_TMP155_filter1['Events']=='POWER UP')|
    (df_TMP155_filter1['Events']=='Ignition ON')]
df_TMP155_geo_land_pu
# Out:
#          Unit        Events                  Date          Landmark
# 3     TMP155       POWER UP  Sep 16 2024 04:28 PM  perimetro urbano
# 4     TMP155    Ignition ON  Sep 16 2024 04:28 PM  perimetro urbano
# 5     TMP155       POWER UP  Sep 16 2024 04:28 PM  perimetro urbano
# 10    TMP155       POWER UP  Sep 10 2024 12:33 PM  perimetro urbano
# 11    TMP155    Ignition ON  Sep 10 2024 12:33 PM  perimetro urbano
# ...       ...           ...                   ...               ...
# 7747  TMP155   Landmark OUT  Jul 30 2024 06:25 AM  BSN MEDICAL LTDA
# 7748  TMP155   Landmark OUT  Jul 30 2024 06:25 AM  BSN MEDICAL LTDA
# 7749  TMP155    Landmark IN  Jul 30 2024 06:25 AM  BSN MEDICAL LTDA
# 7750  TMP155    Landmark IN  Jul 30 2024 06:25 AM  BSN MEDICAL LTDA
# 7765  TMP155    Ignition ON  Jul 30 2024 05:52 AM  perimetro urbano
#
# [2524 rows x 4 columns]

# %%
df_TMP155_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TMP155_geo_land_pu.csv', index=False)
