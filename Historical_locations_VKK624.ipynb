# %%
import pandas as pd
import numpy as np

# %%
df_VKK624 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VKK624.csv')

# %%
df_VKK624.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23552 entries, 0 to 23551
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     23552 non-null  int64
#  1   Unit         23552 non-null  object
#  2   Events       23552 non-null  object
#  3   Date         23552 non-null  object
#  4   Landmark     10920 non-null  object
#  5   Address      23531 non-null  object
#  6   Speed        23552 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       23552 non-null  object
#  9   Latitude     23552 non-null  float64
#  10  Longitude    23552 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
df_VKK624_filter1=df_VKK624[['Unit','Events','Date','Landmark']]
df_VKK624_filter1
# Out:
#          Unit            Events                  Date                Landmark
# 0      VKK624            Parked  Sep 28 2024 08:49 AM                     JBG
# 1      VKK624            Parked  Sep 28 2024 07:49 AM                     JBG
# 2      VKK624            Parked  Sep 28 2024 07:49 AM                     JBG
# 3      VKK624  Towing/Drifting?  Sep 28 2024 07:49 AM                     JBG
# 4      VKK624      Ignition OFF  Sep 28 2024 07:49 AM                     JBG
# ...       ...               ...                   ...                     ...
# 23547  VKK624       Geofence IN  Jul 30 2024 04:17 AM  Parqueadero Yumbo 2011
# 23548  VKK624       Idle - Stop  Jul 30 2024 04:17 AM         Parqueadero TLQ
# 23549  VKK624       Landmark IN  Jul 30 2024 04:17 AM         Parqueadero TLQ
# 23550  VKK624              Ping  Jul 30 2024 04:17 AM         Parqueadero TLQ
# 23551  VKK624       Idle - Stop  Jul 30 2024 04:17 AM                     NaN
#
# [23552 rows x 4 columns]

# %%
df_VKK624_geo_land_pu=df_VKK624_filter1[
    (df_VKK624_filter1['Events']=='Geofence IN')|
    (df_VKK624_filter1['Events']=='Geofence OUT')|
    (df_VKK624_filter1['Events']=='Landmark IN') |
    (df_VKK624_filter1['Events']=='Landmark OUT')|
    (df_VKK624_filter1['Events']=='POWER UP')|
    (df_VKK624_filter1['Events']=='Ignition ON')]
df_VKK624_geo_land_pu
# Out:
#          Unit        Events                  Date  \
# 10     VKK624  Landmark OUT  Sep 28 2024 07:45 AM
# 15     VKK624   Landmark IN  Sep 28 2024 07:43 AM
# 18     VKK624   Landmark IN  Sep 28 2024 07:43 AM
# 29     VKK624  Landmark OUT  Sep 28 2024 07:37 AM
# 31     VKK624  Landmark OUT  Sep 28 2024 07:36 AM
# ...       ...           ...                   ...
# 23527  VKK624  Landmark OUT  Jul 30 2024 04:27 AM
# 23530  VKK624   Geofence IN  Jul 30 2024 04:26 AM
# 23532  VKK624  Geofence OUT  Jul 30 2024 04:25 AM
# 23547  VKK624   Geofence IN  Jul 30 2024 04:17 AM
# 23549  VKK624   Landmark IN  Jul 30 2024 04:17 AM
#
#                                  Landmark
# 10                               JGB S.A.
# 15                               JGB S.A.
# 18                          Klaxen S.A.S.
# 29                       Alexander Chacon
# 31     Velasquez Rodas Fabio Velquimicos
# ...                                   ...
# 23527                     Parqueadero TLQ
# ...

# %%
df_VKK624_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VKK624_geo_land_pu.csv', index=False)
