# %%
import pandas as pd
import numpy as np

# %%
df_ZNL084 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNL084.csv')

# %%
df_ZNL084.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12441 entries, 0 to 12440
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     12441 non-null  int64
#  1   Unit         12441 non-null  object
#  2   Events       12441 non-null  object
#  3   Date         12441 non-null  object
#  4   Landmark     5039 non-null   object
#  5   Address      12415 non-null  object
#  6   Speed        12441 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       11447 non-null  object
#  9   Latitude     12441 non-null  float64
#  10  Longitude    12441 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.0+ MB

# %%
df_ZNL084_filter1=df_ZNL084[['Unit','Events','Date','Landmark']]
df_ZNL084_filter1
# Out:
#          Unit  Events                  Date         Landmark
# 0      ZNL084  Parked  Sep 27 2024 05:18 PM  Parqueadero TLQ
# 1      ZNL084  Parked  Sep 27 2024 04:18 PM  Parqueadero TLQ
# 2      ZNL084  Parked  Sep 27 2024 03:18 PM  Parqueadero TLQ
# 3      ZNL084  Parked  Sep 27 2024 02:18 PM  Parqueadero TLQ
# 4      ZNL084  Parked  Sep 27 2024 01:17 PM  Parqueadero TLQ
# ...       ...     ...                   ...              ...
# 12436  ZNL084  Parked  Jul 30 2024 04:51 AM              NaN
# 12437  ZNL084  Parked  Jul 30 2024 03:51 AM              NaN
# 12438  ZNL084  Parked  Jul 30 2024 02:51 AM              NaN
# 12439  ZNL084  Parked  Jul 30 2024 01:51 AM              NaN
# 12440  ZNL084  Parked  Jul 30 2024 12:51 AM              NaN
#
# [12441 rows x 4 columns]

# %%
df_ZNL084_geo_land_pu=df_ZNL084_filter1[
    (df_ZNL084_filter1['Events']=='Geofence IN')|
    (df_ZNL084_filter1['Events']=='Geofence OUT')|
    (df_ZNL084_filter1['Events']=='Landmark IN') |
    (df_ZNL084_filter1['Events']=='Landmark OUT')|
    (df_ZNL084_filter1['Events']=='POWER UP')|
    (df_ZNL084_filter1['Events']=='Ignition ON')]
df_ZNL084_geo_land_pu
# Out:
#          Unit        Events                  Date  \
# 36     ZNL084   Ignition ON  Sep 26 2024 08:13 AM
# 51     ZNL084   Ignition ON  Sep 26 2024 07:41 AM
# 85     ZNL084  Landmark OUT  Sep 24 2024 11:03 PM
# 87     ZNL084  Landmark OUT  Sep 24 2024 10:03 PM
# 91     ZNL084      POWER UP  Sep 24 2024 09:02 PM
# ...       ...           ...                   ...
# 12403  ZNL084   Landmark IN  Jul 30 2024 06:05 AM
# 12413  ZNL084  Landmark OUT  Jul 30 2024 06:02 AM
# 12414  ZNL084   Landmark IN  Jul 30 2024 06:01 AM
# 12432  ZNL084   Landmark IN  Jul 30 2024 05:50 AM
# 12435  ZNL084   Ignition ON  Jul 30 2024 05:49 AM
#
#                            Landmark
# 36                  Parqueadero TLQ
# 51                  Parqueadero TLQ
# 85                     PEAJE TARAZA
# 87                     PEAJE CENCAR
# 91                              NaN
# ...                             ...
# 12403  Soluciones Nutritivas S.A.S.
# 12413    Laboratorios Dermanat S.A.
# ...

# %%
df_ZNL084_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNL084_geo_land_pu.csv', index=False)
