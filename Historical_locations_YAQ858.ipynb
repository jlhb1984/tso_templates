# %%
import pandas as pd
import numpy as np

# %%
df_YAQ858 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_YAQ858.csv')

# %%
df_YAQ858.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22634 entries, 0 to 22633
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     22634 non-null  int64
#  1   Unit         22634 non-null  object
#  2   Events       22634 non-null  object
#  3   Date         22634 non-null  object
#  4   Landmark     6979 non-null   object
#  5   Address      22563 non-null  object
#  6   Speed        22634 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       12788 non-null  object
#  9   Latitude     22634 non-null  float64
#  10  Longitude    22634 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df_YAQ858_filter1=df_YAQ858[['Unit','Events','Date','Landmark']]
df_YAQ858_filter1
# Out:
#          Unit        Events                  Date      Landmark
# 0      YAQ858        Parked  Sep 28 2024 08:09 AM           NaN
# 1      YAQ858        Parked  Sep 28 2024 07:09 AM           NaN
# 2      YAQ858        Parked  Sep 28 2024 06:09 AM           NaN
# 3      YAQ858        Parked  Sep 28 2024 05:09 AM           NaN
# 4      YAQ858        Parked  Sep 28 2024 04:09 AM           NaN
# ...       ...           ...                   ...           ...
# 22629  YAQ858  Landmark OUT  Aug 06 2024 10:50 AM  PEAJE CENCAR
# 22630  YAQ858   Ignition ON  Aug 06 2024 10:50 AM  PEAJE CENCAR
# 22631  YAQ858      POWER UP  Aug 06 2024 10:50 AM           NaN
# 22632  YAQ858  Landmark OUT  Aug 06 2024 10:50 AM  PEAJE CENCAR
# 22633  YAQ858   Idle - Stop  Aug 06 2024 10:50 AM  PEAJE CENCAR
#
# [22634 rows x 4 columns]

# %%
df_YAQ858_geo_land_pu=df_YAQ858_filter1[
    (df_YAQ858_filter1['Events']=='Geofence IN')|
    (df_YAQ858_filter1['Events']=='Geofence OUT')|
    (df_YAQ858_filter1['Events']=='Landmark IN') |
    (df_YAQ858_filter1['Events']=='Landmark OUT')|
    (df_YAQ858_filter1['Events']=='POWER UP')|
    (df_YAQ858_filter1['Events']=='Ignition ON')]
df_YAQ858_geo_land_pu
# Out:
#          Unit        Events                  Date             Landmark
# 31     YAQ858   Ignition ON  Sep 27 2024 10:57 PM                  NaN
# 83     YAQ858  Landmark OUT  Sep 27 2024 10:07 PM           Peaje Rozo
# 85     YAQ858   Landmark IN  Sep 27 2024 10:05 PM           Peaje Rozo
# 107    YAQ858  Landmark OUT  Sep 27 2024 09:49 PM  BASCULA  EL CERRITO
# 109    YAQ858   Landmark IN  Sep 27 2024 09:48 PM  BASCULA  EL CERRITO
# ...       ...           ...                   ...                  ...
# 22627  YAQ858   Ignition ON  Aug 06 2024 10:50 AM             Alqueria
# 22629  YAQ858  Landmark OUT  Aug 06 2024 10:50 AM         PEAJE CENCAR
# 22630  YAQ858   Ignition ON  Aug 06 2024 10:50 AM         PEAJE CENCAR
# 22631  YAQ858      POWER UP  Aug 06 2024 10:50 AM                  NaN
# 22632  YAQ858  Landmark OUT  Aug 06 2024 10:50 AM         PEAJE CENCAR
#
# [2181 rows x 4 columns]

# %%
df_YAQ858_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_YAQ858_geo_land_pu.csv', index=False)
