# %%
import pandas as pd
import numpy as np

# %%
df_ZNK734 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNK734.csv')

# %%
df_ZNK734.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     742 non-null    int64
#  1   Unit         742 non-null    object
#  2   Events       742 non-null    object
#  3   Date         742 non-null    object
#  4   Landmark     0 non-null      float64
#  5   Address      742 non-null    object
#  6   Speed        742 non-null    int64
#  7   Temperature  0 non-null      float64
#  8   Driver       742 non-null    object
#  9   Latitude     742 non-null    float64
#  10  Longitude    742 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 63.9+ KB

# %%
df_ZNK734_filter1=df_ZNK734[['Unit','Events','Date','Landmark']]
df_ZNK734_filter1
# Out:
#        Unit  Events                  Date  Landmark
# 0    ZNK734  Parked  Sep 09 2024 06:03 PM       NaN
# 1    ZNK734  Parked  Sep 09 2024 05:02 PM       NaN
# 2    ZNK734  Parked  Sep 09 2024 03:01 PM       NaN
# 3    ZNK734  Parked  Sep 09 2024 02:01 PM       NaN
# 4    ZNK734  Parked  Sep 09 2024 12:00 PM       NaN
# ..      ...     ...                   ...       ...
# 737  ZNK734  Parked  Jul 30 2024 07:19 AM       NaN
# 738  ZNK734  Parked  Jul 30 2024 06:19 AM       NaN
# 739  ZNK734  Parked  Jul 30 2024 03:18 AM       NaN
# 740  ZNK734  Parked  Jul 30 2024 01:18 AM       NaN
# 741  ZNK734  Parked  Jul 30 2024 12:17 AM       NaN
#
# [742 rows x 4 columns]

# %%
df_ZNK734_geo_land_pu=df_ZNK734_filter1[
    (df_ZNK734_filter1['Events']=='Geofence IN')|
    (df_ZNK734_filter1['Events']=='Geofence OUT')|
    (df_ZNK734_filter1['Events']=='Landmark IN') |
    (df_ZNK734_filter1['Events']=='Landmark OUT')|
    (df_ZNK734_filter1['Events']=='POWER UP')|
    (df_ZNK734_filter1['Events']=='Ignition ON')]
df_ZNK734_geo_land_pu
# Out:
# Empty DataFrame
# Columns: [Unit, Events, Date, Landmark]
# Index: []

# %%
df_ZNK734_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNK734_geo_land_pu.csv', index=False)
