# %%
import pandas as pd
import numpy as np

# %%
df_ZNL081 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNL081.csv')

# %%
df_ZNL081.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24206 entries, 0 to 24205
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     24206 non-null  int64
#  1   Unit         24206 non-null  object
#  2   Events       24206 non-null  object
#  3   Date         24206 non-null  object
#  4   Landmark     9539 non-null   object
#  5   Address      24174 non-null  object
#  6   Speed        24206 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       24206 non-null  object
#  9   Latitude     24206 non-null  float64
#  10  Longitude    24206 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
df_ZNL081_filter1=df_ZNL081[['Unit','Events','Date','Landmark']]
df_ZNL081_filter1
# Out:
#          Unit        Events                  Date                Landmark
# 0      ZNL081   Geofence IN  Sep 27 2024 04:28 PM  Parqueadero Yumbo 2011
# 1      ZNL081   Geofence IN  Sep 27 2024 04:28 PM           Geo Parq. TLQ
# 2      ZNL081   Landmark IN  Sep 27 2024 04:28 PM         Parqueadero TLQ
# 3      ZNL081        Parked  Sep 27 2024 04:28 PM         Parqueadero TLQ
# 4      ZNL081  Landmark OUT  Sep 27 2024 04:28 PM         Parqueadero TLQ
# ...       ...           ...                   ...                     ...
# 24201  ZNL081        Parked  Jul 30 2024 04:41 AM                     NaN
# 24202  ZNL081        Parked  Jul 30 2024 03:41 AM                     NaN
# 24203  ZNL081        Parked  Jul 30 2024 02:41 AM                     NaN
# 24204  ZNL081        Parked  Jul 30 2024 01:41 AM                     NaN
# 24205  ZNL081        Parked  Jul 30 2024 12:40 AM                     NaN
#
# [24206 rows x 4 columns]

# %%
df_ZNL081_geo_land_pu=df_ZNL081_filter1[
    (df_ZNL081_filter1['Events']=='Geofence IN')|
    (df_ZNL081_filter1['Events']=='Geofence OUT')|
    (df_ZNL081_filter1['Events']=='Landmark IN') |
    (df_ZNL081_filter1['Events']=='Landmark OUT')|
    (df_ZNL081_filter1['Events']=='POWER UP')|
    (df_ZNL081_filter1['Events']=='Ignition ON')]
df_ZNL081_geo_land_pu
# Out:
#          Unit        Events                  Date                Landmark
# 0      ZNL081   Geofence IN  Sep 27 2024 04:28 PM  Parqueadero Yumbo 2011
# 1      ZNL081   Geofence IN  Sep 27 2024 04:28 PM           Geo Parq. TLQ
# 2      ZNL081   Landmark IN  Sep 27 2024 04:28 PM         Parqueadero TLQ
# 4      ZNL081  Landmark OUT  Sep 27 2024 04:28 PM         Parqueadero TLQ
# 8      ZNL081   Ignition ON  Sep 27 2024 04:28 PM                     NaN
# ...       ...           ...                   ...                     ...
# 24159  ZNL081   Landmark IN  Jul 31 2024 12:22 PM         Parqueadero TLQ
# 24162  ZNL081   Geofence IN  Jul 31 2024 12:20 PM  Parqueadero Yumbo 2011
# 24163  ZNL081   Geofence IN  Jul 31 2024 12:20 PM           Geo Parq. TLQ
# 24164  ZNL081   Landmark IN  Jul 31 2024 12:20 PM         Parqueadero TLQ
# 24169  ZNL081   Ignition ON  Jul 31 2024 12:18 PM                     NaN
#
# [2385 rows x 4 columns]
# ...

# %%
df_ZNL081_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNL081_geo_land_pu.csv', index=False)
