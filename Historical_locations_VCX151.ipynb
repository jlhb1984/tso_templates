# %%
import pandas as pd
import numpy as np

# %%
df_VCX151 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VCX151.csv')

# %%
df_VCX151.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8583 entries, 0 to 8582
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     8583 non-null   int64
#  1   Unit         8583 non-null   object
#  2   Events       8583 non-null   object
#  3   Date         8583 non-null   object
#  4   Landmark     3512 non-null   object
#  5   Address      8582 non-null   object
#  6   Speed        8583 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       8583 non-null   object
#  9   Latitude     8583 non-null   float64
#  10  Longitude    8583 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 737.7+ KB

# %%
df_VCX151_filter1=df_VCX151[['Unit','Events','Date','Landmark']]
df_VCX151_filter1
# Out:
#         Unit          Events                  Date          Landmark
# 0     VCX151          Parked  Sep 28 2024 08:41 AM  parq. La Luciana
# 1     VCX151          Parked  Sep 28 2024 07:40 AM  parq. La Luciana
# 2     VCX151          Parked  Sep 28 2024 06:40 AM  parq. La Luciana
# 3     VCX151          Parked  Sep 28 2024 05:39 AM  parq. La Luciana
# 4     VCX151          Parked  Sep 28 2024 04:39 AM  parq. La Luciana
# ...      ...             ...                   ...               ...
# 8578  VCX151        GPS Lost  Aug 01 2024 03:56 PM               NaN
# 8579  VCX151      Idle Alert  Aug 01 2024 03:54 PM               NaN
# 8580  VCX151        POWER UP  Aug 01 2024 03:49 PM               NaN
# 8581  VCX151  Power Restored  Aug 01 2024 03:49 PM               NaN
# 8582  VCX151     Ignition ON  Aug 01 2024 03:49 PM               NaN
#
# [8583 rows x 4 columns]

# %%
df_VCX151_geo_land_pu=df_VCX151_filter1[
    (df_VCX151_filter1['Events']=='Geofence IN')|
    (df_VCX151_filter1['Events']=='Geofence OUT')|
    (df_VCX151_filter1['Events']=='Landmark IN') |
    (df_VCX151_filter1['Events']=='Landmark OUT')|
    (df_VCX151_filter1['Events']=='POWER UP')|
    (df_VCX151_filter1['Events']=='Ignition ON')]
df_VCX151_geo_land_pu
# Out:
#         Unit        Events                  Date                Landmark
# 16    VCX151   Landmark IN  Sep 27 2024 05:36 PM        parq. La Luciana
# 19    VCX151  Landmark OUT  Sep 27 2024 05:33 PM  Parmalat Colombia LTDA
# 21    VCX151   Landmark IN  Sep 27 2024 05:32 PM  Parmalat Colombia LTDA
# 23    VCX151  Landmark OUT  Sep 27 2024 05:32 PM          Brenntag Yumbo
# 26    VCX151   Ignition ON  Sep 27 2024 05:26 PM          Brenntag Yumbo
# ...      ...           ...                   ...                     ...
# 8560  VCX151   Ignition ON  Aug 03 2024 07:52 AM                     NaN
# 8567  VCX151   Ignition ON  Aug 02 2024 05:49 PM                     NaN
# 8571  VCX151      POWER UP  Aug 02 2024 02:31 PM                     NaN
# 8580  VCX151      POWER UP  Aug 01 2024 03:49 PM                     NaN
# 8582  VCX151   Ignition ON  Aug 01 2024 03:49 PM                     NaN
#
# [1671 rows x 4 columns]

# %%
df_VCX151_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VCX151_geo_land_pu.csv', index=False)
