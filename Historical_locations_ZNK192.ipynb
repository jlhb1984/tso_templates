# %%
import pandas as pd
import numpy as np

# %%
df_ZNK192 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNK192.csv')

# %%
df_ZNK192.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5479 entries, 0 to 5478
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     5479 non-null   int64
#  1   Unit         5479 non-null   object
#  2   Events       5479 non-null   object
#  3   Date         5479 non-null   object
#  4   Landmark     2120 non-null   object
#  5   Address      5307 non-null   object
#  6   Speed        5479 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       5479 non-null   object
#  9   Latitude     5479 non-null   float64
#  10  Longitude    5479 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 471.0+ KB

# %%
df_ZNK192_filter1=df_ZNK192[['Unit','Events','Date','Landmark']]
df_ZNK192_filter1
# Out:
#         Unit       Events                  Date         Landmark
# 0     ZNK192       Parked  Sep 28 2024 07:48 AM  Parqueadero TLQ
# 1     ZNK192       Parked  Sep 28 2024 03:48 AM  Parqueadero TLQ
# 2     ZNK192       Parked  Sep 27 2024 11:48 PM  Parqueadero TLQ
# 3     ZNK192       Parked  Sep 27 2024 07:48 PM  Parqueadero TLQ
# 4     ZNK192       Parked  Sep 27 2024 03:48 PM  Parqueadero TLQ
# ...      ...          ...                   ...              ...
# 5474  ZNK192  Idle - Stop  Aug 12 2024 11:22 AM     PEAJE CENCAR
# 5475  ZNK192     POWER UP  Aug 12 2024 11:20 AM              NaN
# 5476  ZNK192     POWER UP  Aug 12 2024 11:20 AM              NaN
# 5477  ZNK192     POWER UP  Aug 12 2024 11:19 AM              NaN
# 5478  ZNK192  Ignition ON  Aug 12 2024 11:17 AM              NaN
#
# [5479 rows x 4 columns]

# %%
df_ZNK192_geo_land_pu=df_ZNK192_filter1[
    (df_ZNK192_filter1['Events']=='Geofence IN')|
    (df_ZNK192_filter1['Events']=='Geofence OUT')|
    (df_ZNK192_filter1['Events']=='Landmark IN') |
    (df_ZNK192_filter1['Events']=='Landmark OUT')|
    (df_ZNK192_filter1['Events']=='POWER UP')|
    (df_ZNK192_filter1['Events']=='Ignition ON')]
df_ZNK192_geo_land_pu
# Out:
#         Unit        Events                  Date         Landmark
# 16    ZNK192   Ignition ON  Sep 26 2024 07:26 AM  Parqueadero TLQ
# 25    ZNK192  Landmark OUT  Sep 25 2024 03:01 PM     PEAJE CENCAR
# 26    ZNK192   Ignition ON  Sep 25 2024 03:01 PM     PEAJE CENCAR
# 27    ZNK192      POWER UP  Sep 25 2024 10:31 AM              NaN
# 28    ZNK192   Ignition ON  Sep 25 2024 10:31 AM  Parqueadero TLQ
# ...      ...           ...                   ...              ...
# 5473  ZNK192  Landmark OUT  Aug 12 2024 11:22 AM     PEAJE CENCAR
# 5475  ZNK192      POWER UP  Aug 12 2024 11:20 AM              NaN
# 5476  ZNK192      POWER UP  Aug 12 2024 11:20 AM              NaN
# 5477  ZNK192      POWER UP  Aug 12 2024 11:19 AM              NaN
# 5478  ZNK192   Ignition ON  Aug 12 2024 11:17 AM              NaN
#
# [1159 rows x 4 columns]

# %%
df_ZNK192_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNK192_geo_land_pu.csv', index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
