# %%
import pandas as pd
import numpy as np

# %%
df_YAP238 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_YAP238.csv')

# %%
df_YAP238.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     50000 non-null  int64
#  1   Unit         50000 non-null  object
#  2   Events       50000 non-null  object
#  3   Date         50000 non-null  object
#  4   Landmark     44779 non-null  object
#  5   Address      49966 non-null  object
#  6   Speed        50000 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       50000 non-null  object
#  9   Latitude     50000 non-null  float64
#  10  Longitude    50000 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 4.2+ MB

# %%
df_YAP238_filter1=df_YAP238[['Unit','Events','Date','Landmark']]
df_YAP238_filter1
# Out:
#          Unit       Events                  Date                    Landmark
# 0      YAP238  Idle - Stop  Sep 27 2024 06:01 PM       Parqueadero Eds la 42
# 1      YAP238  Idle - Stop  Sep 27 2024 06:00 PM       Parqueadero Eds la 42
# 2      YAP238  Idle - Stop  Sep 27 2024 05:59 PM       Parqueadero Eds la 42
# 3      YAP238  Idle - Stop  Sep 27 2024 05:58 PM       Parqueadero Eds la 42
# 4      YAP238  Idle - Stop  Sep 27 2024 05:57 PM       Parqueadero Eds la 42
# ...       ...          ...                   ...                         ...
# 49995  YAP238  Idle - Stop  Jul 30 2024 12:04 AM  parq. estrellas del futuro
# 49996  YAP238  Idle - Stop  Jul 30 2024 12:03 AM  parq. estrellas del futuro
# 49997  YAP238  Idle - Stop  Jul 30 2024 12:02 AM  parq. estrellas del futuro
# 49998  YAP238  Idle - Stop  Jul 30 2024 12:01 AM  parq. estrellas del futuro
# 49999  YAP238  Idle - Stop  Jul 30 2024 12:00 AM  parq. estrellas del futuro
#
# [50000 rows x 4 columns]

# %%
df_YAP238_geo_land_pu=df_YAP238_filter1[
    (df_YAP238_filter1['Events']=='Geofence IN')|
    (df_YAP238_filter1['Events']=='Geofence OUT')|
    (df_YAP238_filter1['Events']=='Landmark IN') |
    (df_YAP238_filter1['Events']=='Landmark OUT')|
    (df_YAP238_filter1['Events']=='POWER UP')|
    (df_YAP238_filter1['Events']=='Ignition ON')]
df_YAP238_geo_land_pu
# Out:
#          Unit        Events                  Date                    Landmark
# 203    YAP238   Ignition ON  Sep 27 2024 02:42 PM       Parqueadero Eds la 42
# 212    YAP238   Landmark IN  Sep 27 2024 02:35 PM       Parqueadero Eds la 42
# 226    YAP238  Landmark OUT  Sep 27 2024 02:27 PM  Crucero Palmira Candelaria
# 231    YAP238   Landmark IN  Sep 27 2024 02:25 PM  Crucero Palmira Candelaria
# 246    YAP238  Landmark OUT  Sep 27 2024 02:14 PM   Eds terpel El Bolo Comaju
# ...       ...           ...                   ...                         ...
# 49524  YAP238  Landmark OUT  Jul 30 2024 08:34 AM  Crucero Palmira Candelaria
# 49527  YAP238   Landmark IN  Jul 30 2024 08:33 AM  Crucero Palmira Candelaria
# 49535  YAP238   Ignition ON  Jul 30 2024 08:29 AM                         NaN
# 49546  YAP238  Landmark OUT  Jul 30 2024 08:23 AM       Parqueadero Eds la 42
# 49550  YAP238   Ignition ON  Jul 30 2024 08:21 AM  parq. estrellas del futuro
#
# [1226 rows x 4 columns]

# %%
df_YAP238_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_YAP238_geo_land_pu.csv', index=False)
