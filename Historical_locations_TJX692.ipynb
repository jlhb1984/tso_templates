# %%
import pandas as pd
import numpy as np

# %%
df_TJX692 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TJX692.csv')

# %%
df_TJX692.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11847 entries, 0 to 11846
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     11847 non-null  int64
#  1   Unit         11847 non-null  object
#  2   Events       11847 non-null  object
#  3   Date         11847 non-null  object
#  4   Landmark     6917 non-null   object
#  5   Address      11821 non-null  object
#  6   Speed        11847 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       11847 non-null  object
#  9   Latitude     11847 non-null  float64
#  10  Longitude    11847 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1018.2+ KB

# %%
df_TJX692_filter1=df_TJX692[['Unit','Events','Date','Landmark']]
df_TJX692_filter1
# Out:
#          Unit        Events                  Date         Landmark
# 0      TJX692   Ignition ON  Sep 28 2024 10:44 AM    TALLER WILMER
# 1      TJX692        Parked  Sep 28 2024 10:43 AM    TALLER WILMER
# 2      TJX692  Ignition OFF  Sep 28 2024 10:33 AM    TALLER WILMER
# 3      TJX692     First Fix  Sep 28 2024 10:29 AM    TALLER WILMER
# 4      TJX692   Ignition ON  Sep 28 2024 10:28 AM    TALLER WILMER
# ...       ...           ...                   ...              ...
# 11842  TJX692        Parked  Jul 30 2024 04:48 AM  Parqueadero TLQ
# 11843  TJX692        Parked  Jul 30 2024 03:48 AM  Parqueadero TLQ
# 11844  TJX692        Parked  Jul 30 2024 02:48 AM  Parqueadero TLQ
# 11845  TJX692        Parked  Jul 30 2024 01:48 AM  Parqueadero TLQ
# 11846  TJX692        Parked  Jul 30 2024 12:48 AM  Parqueadero TLQ
#
# [11847 rows x 4 columns]

# %%
df_TJX692_geo_land_pu=df_TJX692_filter1[
    (df_TJX692_filter1['Events']=='Geofence IN')|
    (df_TJX692_filter1['Events']=='Geofence OUT')|
    (df_TJX692_filter1['Events']=='Landmark IN') |
    (df_TJX692_filter1['Events']=='Landmark OUT')|
    (df_TJX692_filter1['Events']=='POWER UP')|
    (df_TJX692_filter1['Events']=='Ignition ON')]
df_TJX692_geo_land_pu
# Out:
#          Unit        Events                  Date                Landmark
# 0      TJX692   Ignition ON  Sep 28 2024 10:44 AM           TALLER WILMER
# 4      TJX692   Ignition ON  Sep 28 2024 10:28 AM           TALLER WILMER
# 9      TJX692   Ignition ON  Sep 28 2024 07:55 AM           TALLER WILMER
# 12     TJX692   Ignition ON  Sep 28 2024 07:47 AM           TALLER WILMER
# 16     TJX692   Ignition ON  Sep 28 2024 07:27 AM           TALLER WILMER
# ...       ...           ...                   ...                     ...
# 11832  TJX692   Landmark IN  Jul 30 2024 07:03 AM               Reenvases
# 11836  TJX692  Geofence OUT  Jul 30 2024 06:59 AM  Parqueadero Yumbo 2011
# 11837  TJX692  Geofence OUT  Jul 30 2024 06:59 AM           Geo Parq. TLQ
# 11838  TJX692  Landmark OUT  Jul 30 2024 06:59 AM         Parqueadero TLQ
# 11839  TJX692   Ignition ON  Jul 30 2024 06:53 AM         Parqueadero TLQ
#
# [2618 rows x 4 columns]

# %%
df_TJX692_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TJX692_geo_land_pu.csv', index=False)
