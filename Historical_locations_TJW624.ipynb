# %%
import pandas as pd
import numpy as np

# %%
df_TJW624 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_TJW624.csv')

# %%
df_TJW624.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11707 entries, 0 to 11706
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     11707 non-null  int64
#  1   Unit         11707 non-null  object
#  2   Events       11707 non-null  object
#  3   Date         11707 non-null  object
#  4   Landmark     6685 non-null   object
#  5   Address      11705 non-null  object
#  6   Speed        11707 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       11707 non-null  object
#  9   Latitude     11707 non-null  float64
#  10  Longitude    11707 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1006.2+ KB

# %%
df_TJW624_filter1=df_TJW624[['Unit','Events','Date','Landmark']]
df_TJW624_filter1
# Out:
#          Unit        Events                  Date               Landmark
# 0      TJW624  Ignition OFF  Sep 27 2024 11:38 PM  Parq. Manuela Beltran
# 1      TJW624     First Fix  Sep 27 2024 11:38 PM  Parq. Manuela Beltran
# 2      TJW624   Ignition ON  Sep 27 2024 11:38 PM  Parq. Manuela Beltran
# 3      TJW624        Parked  Sep 27 2024 11:10 PM  Parq. Manuela Beltran
# 4      TJW624  Ignition OFF  Sep 27 2024 11:00 PM  Parq. Manuela Beltran
# ...       ...           ...                   ...                    ...
# 11702  TJW624    Idle Alert  Jul 30 2024 05:55 AM  Parq. Manuela Beltran
# 11703  TJW624     First Fix  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
# 11704  TJW624      POWER UP  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
# 11705  TJW624   Ignition ON  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
# 11706  TJW624      POWER UP  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
#
# [11707 rows x 4 columns]

# %%
df_TJW624_geo_land_pu=df_TJW624_filter1[
    (df_TJW624_filter1['Events']=='Geofence IN')|
    (df_TJW624_filter1['Events']=='Geofence OUT')|
    (df_TJW624_filter1['Events']=='Landmark IN') |
    (df_TJW624_filter1['Events']=='Landmark OUT')|
    (df_TJW624_filter1['Events']=='POWER UP')|
    (df_TJW624_filter1['Events']=='Ignition ON')]
df_TJW624_geo_land_pu
# Out:
#          Unit        Events                  Date               Landmark
# 2      TJW624   Ignition ON  Sep 27 2024 11:38 PM  Parq. Manuela Beltran
# 6      TJW624      POWER UP  Sep 27 2024 10:59 PM  Parq. Manuela Beltran
# 7      TJW624      POWER UP  Sep 27 2024 10:59 PM  Parq. Manuela Beltran
# 8      TJW624   Ignition ON  Sep 27 2024 10:59 PM  Parq. Manuela Beltran
# 10     TJW624   Landmark IN  Sep 27 2024 10:40 PM  Parq. Manuela Beltran
# ...       ...           ...                   ...                    ...
# 11698  TJW624   Ignition ON  Jul 30 2024 06:17 AM       perimetro urbano
# 11700  TJW624  Landmark OUT  Jul 30 2024 06:00 AM  Parq. Manuela Beltran
# 11704  TJW624      POWER UP  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
# 11705  TJW624   Ignition ON  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
# 11706  TJW624      POWER UP  Jul 30 2024 05:50 AM  Parq. Manuela Beltran
#
# [3048 rows x 4 columns]

# %%
df_TJW624_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_TJW624_geo_land_pu.csv', index=False)
