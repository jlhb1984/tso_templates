# %%
import pandas as pd
import numpy as np

# %%
df_ZNL193 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_ZNL193.csv')

# %%
df_ZNL193.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18953 entries, 0 to 18952
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     18953 non-null  int64
#  1   Unit         18953 non-null  object
#  2   Events       18953 non-null  object
#  3   Date         18953 non-null  object
#  4   Landmark     3817 non-null   object
#  5   Address      18950 non-null  object
#  6   Speed        18953 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       18953 non-null  object
#  9   Latitude     18953 non-null  float64
#  10  Longitude    18953 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
df_ZNL193_filter1=df_ZNL193[['Unit','Events','Date','Landmark']]
df_ZNL193_filter1
# Out:
#          Unit       Events                  Date          Landmark
# 0      ZNL193       Parked  Sep 27 2024 04:33 PM               NaN
# 1      ZNL193       Parked  Sep 27 2024 02:32 PM               NaN
# 2      ZNL193       Parked  Sep 27 2024 01:32 PM               NaN
# 3      ZNL193       Parked  Sep 27 2024 12:34 PM               NaN
# 4      ZNL193       Parked  Sep 27 2024 12:32 PM               NaN
# ...       ...          ...                   ...               ...
# 18948  ZNL193   Idle Alert  Jul 30 2024 07:24 AM  Sucroal Porteria
# 18949  ZNL193    First Fix  Jul 30 2024 07:20 AM  Sucroal Porteria
# 18950  ZNL193     POWER UP  Jul 30 2024 07:19 AM  Sucroal Porteria
# 18951  ZNL193  Ignition ON  Jul 30 2024 07:19 AM  Sucroal Porteria
# 18952  ZNL193     POWER UP  Jul 30 2024 07:19 AM  Sucroal Porteria
#
# [18953 rows x 4 columns]

# %%
df_ZNL193_geo_land_pu=df_ZNL193_filter1[
    (df_ZNL193_filter1['Events']=='Geofence IN')|
    (df_ZNL193_filter1['Events']=='Geofence OUT')|
    (df_ZNL193_filter1['Events']=='Landmark IN') |
    (df_ZNL193_filter1['Events']=='Landmark OUT')|
    (df_ZNL193_filter1['Events']=='POWER UP')|
    (df_ZNL193_filter1['Events']=='Ignition ON')]
df_ZNL193_geo_land_pu
# Out:
#          Unit        Events                  Date                 Landmark
# 165    ZNL193   Ignition ON  Sep 27 2024 04:49 AM                      NaN
# 207    ZNL193   Ignition ON  Sep 26 2024 09:37 PM                      NaN
# 227    ZNL193  Landmark OUT  Sep 26 2024 07:39 PM      eds terpel Chinauta
# 230    ZNL193   Landmark IN  Sep 26 2024 07:35 PM      eds terpel Chinauta
# 233    ZNL193   Landmark IN  Sep 26 2024 07:33 PM      eds terpel Chinauta
# ...       ...           ...                   ...                      ...
# 18941  ZNL193  Landmark OUT  Jul 30 2024 07:39 AM  Retorno Palm-Candelaria
# 18945  ZNL193  Landmark OUT  Jul 30 2024 07:34 AM         Sucroal Porteria
# 18950  ZNL193      POWER UP  Jul 30 2024 07:19 AM         Sucroal Porteria
# 18951  ZNL193   Ignition ON  Jul 30 2024 07:19 AM         Sucroal Porteria
# 18952  ZNL193      POWER UP  Jul 30 2024 07:19 AM         Sucroal Porteria
#
# [1032 rows x 4 columns]
# ...

# %%
df_ZNL193_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_ZNL193_geo_land_pu.csv', index=False)
