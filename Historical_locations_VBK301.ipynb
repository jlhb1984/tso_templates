# %%
import pandas as pd
import numpy as np

# %%
df_VBK301 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VBK301.csv')

# %%
df_VBK301.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     50000 non-null  int64
#  1   Unit         50000 non-null  object
#  2   Events       50000 non-null  object
#  3   Date         50000 non-null  object
#  4   Landmark     44980 non-null  object
#  5   Address      49972 non-null  object
#  6   Speed        50000 non-null  int64
#  7   Temperature  0 non-null      float64
#  8   Driver       50000 non-null  object
#  9   Latitude     50000 non-null  float64
#  10  Longitude    50000 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 4.2+ MB

# %%
df_VBK301_filter1=df_VBK301[['Unit','Events','Date','Landmark']]
df_VBK301_filter1
# Out:
#          Unit       Events                  Date                    Landmark
# 0      VBK301  Idle - Stop  Sep 12 2024 03:41 AM       Parqueadero Eds la 42
# 1      VBK301  Idle - Stop  Sep 12 2024 03:40 AM       Parqueadero Eds la 42
# 2      VBK301  Idle - Stop  Sep 12 2024 03:39 AM       Parqueadero Eds la 42
# 3      VBK301  Idle - Stop  Sep 12 2024 03:38 AM       Parqueadero Eds la 42
# 4      VBK301  Idle - Stop  Sep 12 2024 03:37 AM       Parqueadero Eds la 42
# ...       ...          ...                   ...                         ...
# 49995  VBK301       Parked  Jul 30 2024 04:02 AM  parq. estrellas del futuro
# 49996  VBK301       Parked  Jul 30 2024 03:02 AM  parq. estrellas del futuro
# 49997  VBK301       Parked  Jul 30 2024 02:01 AM  parq. estrellas del futuro
# 49998  VBK301       Parked  Jul 30 2024 01:01 AM  parq. estrellas del futuro
# 49999  VBK301       Parked  Jul 30 2024 12:01 AM  parq. estrellas del futuro
#
# [50000 rows x 4 columns]

# %%
df_VBK301_geo_land_pu=df_VBK301_filter1[
    (df_VBK301_filter1['Events']=='Geofence IN')|
    (df_VBK301_filter1['Events']=='Geofence OUT')|
    (df_VBK301_filter1['Events']=='Landmark IN') |
    (df_VBK301_filter1['Events']=='Landmark OUT')|
    (df_VBK301_filter1['Events']=='POWER UP')|
    (df_VBK301_filter1['Events']=='Ignition ON')]
df_VBK301_geo_land_pu
# Out:
#          Unit        Events                  Date                    Landmark
# 297    VBK301  Landmark OUT  Sep 11 2024 10:44 PM          Lavadero EDS la 42
# 303    VBK301   Ignition ON  Sep 11 2024 10:41 PM       Parqueadero Eds la 42
# 306    VBK301  Landmark OUT  Sep 11 2024 10:41 PM          Lavadero EDS la 42
# 308    VBK301  Landmark OUT  Sep 11 2024 10:41 PM          Lavadero EDS la 42
# 314    VBK301   Landmark IN  Sep 11 2024 10:37 PM          Lavadero EDS la 42
# ...       ...           ...                   ...                         ...
# 49869  VBK301   Ignition ON  Jul 31 2024 11:00 AM       Parqueadero Eds la 42
# 49936  VBK301   Ignition ON  Jul 31 2024 09:58 AM       Parqueadero Eds la 42
# 49967  VBK301  Landmark OUT  Jul 30 2024 08:02 AM          Lavadero EDS la 42
# 49987  VBK301   Landmark IN  Jul 30 2024 07:44 AM          Lavadero EDS la 42
# 49991  VBK301   Ignition ON  Jul 30 2024 07:44 AM  parq. estrellas del futuro
#
# [1199 rows x 4 columns]

# %%
df_VBK301_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VBK301_geo_land_pu.csv', index=False)
