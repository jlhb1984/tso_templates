# %%
import pandas as pd
import numpy as np

# %%
df_KUM480 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_KUM480.csv')

# %%
df_KUM480.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5616 entries, 0 to 5615
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     5616 non-null   int64
#  1   Unit         5616 non-null   object
#  2   Events       5616 non-null   object
#  3   Date         5616 non-null   object
#  4   Landmark     2120 non-null   object
#  5   Address      5614 non-null   object
#  6   Speed        5616 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       5616 non-null   object
#  9   Latitude     5616 non-null   float64
#  10  Longitude    5616 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 482.8+ KB

# %%
df_KUM480_filter1=df_KUM480[['Unit','Events','Date','Landmark']]
df_KUM480_filter1
# Out:
#         Unit          Events                  Date Landmark
# 0     KUM480       First Fix  Sep 28 2024 11:32 AM      NaN
# 1     KUM480     Ignition ON  Sep 28 2024 11:32 AM      NaN
# 2     KUM480          Parked  Sep 28 2024 10:52 AM      NaN
# 3     KUM480          Parked  Sep 28 2024 10:02 AM      NaN
# 4     KUM480    Ignition OFF  Sep 28 2024 09:52 AM      NaN
# ...      ...             ...                   ...      ...
# 5611  KUM480      Idle Alert  Sep 01 2024 07:56 AM      NaN
# 5612  KUM480       First Fix  Sep 01 2024 07:52 AM      NaN
# 5613  KUM480        POWER UP  Sep 01 2024 07:51 AM      NaN
# 5614  KUM480  Power Restored  Sep 01 2024 07:51 AM      NaN
# 5615  KUM480     Ignition ON  Sep 01 2024 07:51 AM      NaN
#
# [5616 rows x 4 columns]

# %%
df_KUM480_geo_land_pu=df_KUM480_filter1[
    (df_KUM480_filter1['Events']=='Geofence IN')|
    (df_KUM480_filter1['Events']=='Geofence OUT')|
    (df_KUM480_filter1['Events']=='Landmark IN') |
    (df_KUM480_filter1['Events']=='Landmark OUT')|
    (df_KUM480_filter1['Events']=='POWER UP')|
    (df_KUM480_filter1['Events']=='Ignition ON')]
df_KUM480_geo_land_pu
# Out:
#         Unit        Events                  Date       Landmark
# 1     KUM480   Ignition ON  Sep 28 2024 11:32 AM            NaN
# 5     KUM480   Ignition ON  Sep 28 2024 09:51 AM            NaN
# 23    KUM480   Ignition ON  Sep 28 2024 09:09 AM            NaN
# 25    KUM480   Ignition ON  Sep 28 2024 09:01 AM            NaN
# 27    KUM480   Ignition ON  Sep 28 2024 08:52 AM            NaN
# ...      ...           ...                   ...            ...
# 5603  KUM480  Landmark OUT  Sep 01 2024 08:45 AM  Quimicol Ltda
# 5605  KUM480   Landmark IN  Sep 01 2024 08:43 AM  Quimicol Ltda
# 5607  KUM480   Ignition ON  Sep 01 2024 08:40 AM            NaN
# 5613  KUM480      POWER UP  Sep 01 2024 07:51 AM            NaN
# 5615  KUM480   Ignition ON  Sep 01 2024 07:51 AM            NaN
#
# [1312 rows x 4 columns]

# %%
df_KUM480_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_KUM480_geo_land_pu.csv', index=False)
