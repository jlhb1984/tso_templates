# %%
import pandas as pd
import numpy as np

# %%
df_VCC209 = pd.read_csv('/content/drive/MyDrive/Transliquidos/Colab/Historical_locations_VCC209.csv')

# %%
df_VCC209.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sequence     4617 non-null   int64
#  1   Unit         4617 non-null   object
#  2   Events       4617 non-null   object
#  3   Date         4617 non-null   object
#  4   Landmark     3008 non-null   object
#  5   Address      4612 non-null   object
#  6   Speed        4617 non-null   int64
#  7   Temperature  0 non-null      float64
#  8   Driver       4617 non-null   object
#  9   Latitude     4617 non-null   float64
#  10  Longitude    4617 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 396.9+ KB

# %%
df_VCC209_filter1=df_VCC209[['Unit','Events','Date','Landmark']]
df_VCC209_filter1
# Out:
#         Unit          Events                  Date              Landmark
# 0     VCC209          Parked  Sep 28 2024 09:36 AM  C&F diesel inyection
# 1     VCC209    Ignition OFF  Sep 28 2024 09:25 AM  C&F diesel inyection
# 2     VCC209    Landmark OUT  Sep 28 2024 09:17 AM      Alexander Chacon
# 3     VCC209       First Fix  Sep 28 2024 09:17 AM      Alexander Chacon
# 4     VCC209     Ignition ON  Sep 28 2024 09:16 AM      Alexander Chacon
# ...      ...             ...                   ...                   ...
# 4612  VCC209           Drive  Jul 30 2024 05:08 AM      Sucroal Porteria
# 4613  VCC209       First Fix  Jul 30 2024 05:03 AM      Sucroal Porteria
# 4614  VCC209     Ignition ON  Jul 30 2024 05:02 AM      Sucroal Porteria
# 4615  VCC209        POWER UP  Jul 30 2024 05:02 AM      Sucroal Porteria
# 4616  VCC209  Power Restored  Jul 30 2024 05:02 AM      Sucroal Porteria
#
# [4617 rows x 4 columns]

# %%
df_VCC209_geo_land_pu=df_VCC209_filter1[
    (df_VCC209_filter1['Events']=='Geofence IN')|
    (df_VCC209_filter1['Events']=='Geofence OUT')|
    (df_VCC209_filter1['Events']=='Landmark IN') |
    (df_VCC209_filter1['Events']=='Landmark OUT')|
    (df_VCC209_filter1['Events']=='POWER UP')|
    (df_VCC209_filter1['Events']=='Ignition ON')]
df_VCC209_geo_land_pu
# Out:
#         Unit        Events                  Date                    Landmark
# 2     VCC209  Landmark OUT  Sep 28 2024 09:17 AM            Alexander Chacon
# 4     VCC209   Ignition ON  Sep 28 2024 09:16 AM            Alexander Chacon
# 142   VCC209   Landmark IN  Sep 20 2024 06:27 PM            Alexander Chacon
# 144   VCC209   Landmark IN  Sep 20 2024 06:24 PM  Lab diésel inyection C & F
# 146   VCC209  Landmark OUT  Sep 20 2024 06:23 PM  Lab diésel inyection C & F
# ...      ...           ...                   ...                         ...
# 4601  VCC209  Landmark OUT  Jul 30 2024 05:20 AM     Retorno Palm-Candelaria
# 4603  VCC209   Landmark IN  Jul 30 2024 05:20 AM     Retorno Palm-Candelaria
# 4607  VCC209  Landmark OUT  Jul 30 2024 05:15 AM            Sucroal Porteria
# 4614  VCC209   Ignition ON  Jul 30 2024 05:02 AM            Sucroal Porteria
# 4615  VCC209      POWER UP  Jul 30 2024 05:02 AM            Sucroal Porteria
#
# [1024 rows x 4 columns]

# %%
df_VCC209_geo_land_pu.to_csv('/content/drive/MyDrive/Transliquidos/Colab/df_VCC209_geo_land_pu.csv', index=False)
